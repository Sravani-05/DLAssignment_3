# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravani-05/DLAssignment_3/blob/main/DeepNN_with_pytorch_builtin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Write a colab in pytorch classes based - 3 layer deep neural network for non linear regression using pytorch builtin functionality of modules, backprop etc.**

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
n = 200
d = 3
x = torch.rand(n,d)
weights_true = torch.tensor([[2, 1,-1],[3,0,-1]]).T
bias_true = torch.tensor([[0.5],[0.1]])

y_true = torch.matmul((x ** 2).float() , weights_true.float()) + torch.matmul(x.float() , weights_true.float()) + bias_true.T.float()
print(f'x: {x.shape}, weights: {weights_true.shape}, bias: {bias_true.shape}, y: {y_true.shape}')
# Out:
# x: torch.Size([200, 3]), weights: torch.Size([3, 2]), bias: torch.Size([2, 1]), y: torch.Size([200, 2])

# %%
from sklearn.manifold import TSNE
view = TSNE(n_components=2, n_jobs=5).fit_transform(x)
view.shape
# Out:
# (200, 2)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
#y_pred = y_pred.astype('int')
fig = plt.figure(figsize=(10,5))
tsne = fig.add_subplot(111, projection='3d')
tsne.scatter(*zip(*view))
plt.show()

# %%
import math
import torch.nn as nn


class TorchModel(nn.Module):
  def __init__(self, input_dim, num_hidden):
    super().__init__()
    self.linear1 = nn.Linear(input_dim, num_hidden)
    self.relu = nn.ReLU()
    self.linear2 = nn.Linear(num_hidden, 2)
  
  def forward(self, x):
    l1 = self.linear1(x)
    r = self.relu(l1)
    l2 = self.linear2(r)
    return l2


loss = nn.MSELoss()
model = TorchModel(d, 4)
x_tensor = torch.tensor(x).float()
y_true_tensor = torch.tensor(y_true).float()
y_pred_tensor = model(x_tensor)
loss_value = loss(y_pred_tensor, y_true_tensor)
print(loss_value)
# Out:
# tensor(5.2133, grad_fn=<MseLossBackward0>)
# <ipython-input-5-48b7f9388d16>:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_tensor = torch.tensor(x).float()
# <ipython-input-5-48b7f9388d16>:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true_tensor = torch.tensor(y_true).float()

# %%
# Test just one forward and backward step
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

optimizer.zero_grad()
y_pred_tensor = model(x_tensor)
loss_value = loss(y_pred_tensor, y_true_tensor)
print(loss_value)
loss_gradient = loss_value.backward()
optimizer.step()

y_pred_tensor = model(x_tensor)
loss_value = loss(y_pred_tensor, y_true_tensor)
print(loss_value)
# Out:
# tensor(5.2133, grad_fn=<MseLossBackward0>)
# tensor(4.7365, grad_fn=<MseLossBackward0>)

# %%
def plot_3d(x, y, y_pred=None):
  import matplotlib.pyplot as plt
  from mpl_toolkits.mplot3d import Axes3D
  fig = plt.figure()
  tsne = fig.add_subplot(111, projection='3d')
  tsne.scatter(x[:, 0], x[:, 1], y[:, 0], label='underlying function')
  if y_pred is not None:
    tsne.scatter(x[:, 0], x[:, 1], y_pred[:, 0], label='our function')
  plt.legend()

# %%
from typing import Callable

def torch_fit(x, y, model: Callable, loss: Callable, lr: float, num_epochs: int):
  optimizer = torch.optim.SGD(model.parameters(), lr=lr)
  for epoch in range(num_epochs):
    optimizer.zero_grad()
    y_pred_tensor = model(x_tensor)
    loss_value = loss(y_pred_tensor, y_true_tensor)
    print(loss_value)
    loss_value.backward()
    optimizer.step()

torch_fit(x_tensor, y_true_tensor, model=model, loss=loss, lr=0.1, num_epochs=40)
plot_3d(x, y_true, model(x_tensor).detach())
# Out:
# tensor(4.7365, grad_fn=<MseLossBackward0>)
# tensor(4.3503, grad_fn=<MseLossBackward0>)
# tensor(4.0375, grad_fn=<MseLossBackward0>)
# tensor(3.7841, grad_fn=<MseLossBackward0>)
# tensor(3.5788, grad_fn=<MseLossBackward0>)
# tensor(3.4126, grad_fn=<MseLossBackward0>)
# tensor(3.2780, grad_fn=<MseLossBackward0>)
# tensor(3.1689, grad_fn=<MseLossBackward0>)
# tensor(3.0806, grad_fn=<MseLossBackward0>)
# tensor(3.0090, grad_fn=<MseLossBackward0>)
# tensor(2.9510, grad_fn=<MseLossBackward0>)
# tensor(2.9040, grad_fn=<MseLossBackward0>)
# tensor(2.8659, grad_fn=<MseLossBackward0>)
# tensor(2.8351, grad_fn=<MseLossBackward0>)
# tensor(2.8101, grad_fn=<MseLossBackward0>)
# tensor(2.7899, grad_fn=<MseLossBackward0>)
# tensor(2.7735, grad_fn=<MseLossBackward0>)
# tensor(2.7602, grad_fn=<MseLossBackward0>)
# tensor(2.7495, grad_fn=<MseLossBackward0>)
# tensor(2.7408, grad_fn=<MseLossBackward0>)
# tensor(2.7337, grad_fn=<MseLossBackward0>)
# tensor(2.7280, grad_fn=<MseLossBackward0>)
# tensor(2.7234, grad_fn=<MseLossBackward0>)
# tensor(2.7196, grad_fn=<MseLossBackward0>)
# tensor(2.7166, grad_fn=<MseLossBackward0>)
# tensor(2.7141, grad_fn=<MseLossBackward0>)
# tensor(2.7121, grad_fn=<MseLossBackward0>)
# tensor(2.7105, grad_fn=<MseLossBackward0>)
# tensor(2.7092, grad_fn=<MseLossBackward0>)
# tensor(2.7082, grad_fn=<MseLossBackward0>)
# tensor(2.7073, grad_fn=<MseLossBackward0>)
# tensor(2.7066, grad_fn=<MseLossBackward0>)
# tensor(2.7060, grad_fn=<MseLossBackward0>)
# tensor(2.7056, grad_fn=<MseLossBackward0>)
# tensor(2.7052, grad_fn=<MseLossBackward0>)
# tensor(2.7049, grad_fn=<MseLossBackward0>)
# tensor(2.7046, grad_fn=<MseLossBackward0>)
# tensor(2.7045, grad_fn=<MseLossBackward0>)
# tensor(2.7043, grad_fn=<MseLossBackward0>)
# tensor(2.7042, grad_fn=<MseLossBackward0>)
